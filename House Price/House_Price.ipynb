# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('data.csv')
df.head(4)
# Out:
#     date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 1  05-02   313000.0       3.0       1.50         1340      7912     1.5
# 2  05-02   342000.0       3.0       2.00         1930     11947     1.0
# 3  05-02   420000.0       3.0       2.25         2000      8030     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0           0     4          5        3370            280      1921
# 1           0     0          3        1340              0      1955
# 2           0     0          4        1930              0      1966
# 3           0     0          4        1000           1000      1963
#
#    yr_renovated                    street       city  statezip country
# 0             0           709 W Blaine St    Seattle  WA 98119     USA
# 1          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# ...

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['date','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','sqft_above','sqft_basement','yr_built','yr_renovated']],df.price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-cd18009e7a51> in <module>
#       1 reg = linear_model.LinearRegression()
# ----> 2 reg.fit(df[['date','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','sqft_above','sqft_basement','yr_built','yr_renovated','street','city','statezip','country']],df.price)
#
# c:\Users\ALWIN\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     517
#     518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
# --> 519                                    y_numeric=True, multi_output=True)
#     520
#     521         if sample_weight is not None:
#
# ...
